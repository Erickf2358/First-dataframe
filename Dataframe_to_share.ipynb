# %% [markdown]
# # Purpose of the notebook

# %% [markdown]
# Explain the opportunities of using dataframes

# %%
import pandas as pd


# Importing project code table
file_path_Projects = r'Your folder location'
file_path_00 = 'CBS_01.xlsx'
sheet_name = 'Allocation_Budget'
df = pd.read_excel(fr'{file_path_Projects}\{file_path_00}', sheet_name=sheet_name)

# %%
df.columns
# Out:
# Index(['Item', 'Descripción', 'Description', 'Unit', 'Qty', 'Unit price',
#        'Price', 'Subtotal', 'Total', 'Control Account'],
#       dtype='object')

# %%
df.groupby(['Control Account', 'Description']).agg({'Price': 'sum'}).reset_index()
# Out:
#         Control Account                                        Description  \
# 0               Ceramic               INSTALLATION OF CERAMICS IN BATHROOM
# 1              Concrete             CONCRETE BEAMS AND SLAB F'C=210 KG/CM2
# 2              Concrete                    CONCRETE COLUMNS F'C=210 KG/CM2
# 3              Concrete                    CONCRETE OVERHANG 1:8 + 25% PM.
# 4              Concrete              CONCRETE SIDEWALKS AND FLOORS E=0.125
# 5              Concrete                                      CONCRETE SINK
# 6              Concrete     CYCLOPIUM CONCRETE 1:10 CEMENT-CONCRETE 30%PG.
# 7              Concrete        FORMWORK AND STRIPPING OF OVERHEAD FORMWORK
# 8            Earthworks                COMPACTED FILLING WITH OWN MATERIAL
# 9            Earthworks                      COMPACTION OF FOUNDATION SOIL
# 10           Earthworks                       DISPOSAL OF SURPLUS MATERIAL
# ...
